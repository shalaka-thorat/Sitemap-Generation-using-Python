# %% [markdown]
# #### What is Sitemap:
#
# A sitemap is a file that provides information about pages, images, videos included on your website.<br>
# Sitemaps are used by search engines like Google for efficient crawling.<br>
#
# There are various sitemap formats such as XML, RSS, Text. XML sitemap format is popularly used and is thus demostrated in further coding cells of this notebook.
#
# #### <font color="green">Use of Sitemap:</font>
#
# A sitemap is used to provide specific information about your website namely, webpages, images on the webpages.<br>
# For example:<br>
# A video sitemap will provide information about the video location, video title, rating and much more.<br>
# An image sitemap will include the location of the images included in a specific webpage.

# %% [markdown]
# #### Types of Sitemap:
#
# Following are the 3 types of sitemaps used widely:
#
# 1) URL Sitemap (Basic Sitemap that most websites use)<br>
# 2) Image Sitemap<br>
# 3) Video Sitemap

# %% [markdown]
# <font color="green">XML Tags used in Sitemap:</font>
#
# Following are the available XML Tags for building a Sitemap:
#
# 1) \<urlset> (Required Tag): This is main parent tag of the file which contains information related to all the URLs. It has an attribute 'xmlns' which defines the schema of the sitemap.<br>
#     \<urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9">
#
#
# 2) \<url> (Required Tag): This is child tag of \<urlset> and is responsible for each URL entry. Further explained tags are child tags of \<url> tag.
#
# 3) \<loc> (Required Tag): This includes URL of the page. It must begin with the protocol like http or https, and end with a trailing slash (/). The URLs must be unique, there should not be any duplicate entries.
#
# 4) \<lastmod> (Optional Tag): This value specifies the last modified date of the page. This date should be in YYYY-MM-DD format. This date should resemble the date on last modification was done to the page, and not the creation date of sitemap.
#
# 5) \<changefreq> (Optional Tag): This indicates about how frequently the page is likely to modify. This value provides information about how often search engines should crawl the page. Valid values are: always, hourly, daily, weekly, monthly, yearly, never
#
# 6) \<priority> (Optional Tag): The priority of URL is a measure of how important this page is relative to other URLs on the website. This value should be between 0.0 to 1.0. The default priority of a page is 0.5. For example, if URL is of homepage, then priority must be 1.0.
#
# Sample XML Sitemap:
#
# \<?xml version="1.0" encoding="UTF-8"?><br>
# \<urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9"><br>
#     &emsp;\<url><br>
#         &emsp;&emsp;\<loc> http://www.abc.com/ \</loc><br>
#         &emsp;&emsp;\<lastmod> 2022-09-01 \</lastmod><br>
#         &emsp;&emsp;\<changefreq> daily \</changefreq><br>
#         &emsp;&emsp;\<priority> 0.9 \</priority>  <br>
#     &emsp;\</url><br>
# \</urlset>

# %% [markdown]
# #### How to construct Sitemap:
#
# Following are the steps through which you can construct a sitemap for your website:
#
# Step 1: Collection of URLs to be included for the sitemap: This includes collecting the URLs which are essential for building sitemap. These might be stored in a database and retrieved. Here, in <i>Part 1</i> of this notebook, we do web-scraping for a single page for demostration purpose. We pre-process all the URLs that are retrieved and store these unique URLs in a list.
#
# Step 2: Creating Sitemap for URLs: From the URLs we stored in Part 1, we construct the sitemap. Depending on the number of URLs, we need to create sitemaps. A sitemap can include <i>Maximum 50,000 URL entries</i> and size of sitemap must be <i>less than 50 MB</i>. This procedure has been explained in <i>Part 2</i> of the notebook.
#
# Step 3: Creation of Sitemap Index: If there are multiple sitemap files created, then you can enlist each entry into a Sitemap Index file. A Sitemap Index can include <i>maximum 50,000 Sitemap entries</i> and size of Sitemap Index must be <i>less than 50 MB</i>. There can be more than 1 Sitemap Index file. XML Format of Sitemap Index file is similar to Sitemap. You will get a detailed view of this in notebook <i>Part 2</i>.
#
# Each URL entry must be unique in a Sitemap, and each Sitemap entry must be unique in Sitemap Index.
#
# Lets deep dive into all of these Parts.

# %% [markdown]
# ### PART 1: Web Scraping of URLs

# %%
# Importing necessary libraries for web-scraping

from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import re
from datetime import datetime

# %%
# Importing libraries for constructing sitemap

from xml.dom import minidom
import os

# %%
# Establishing a request wih the website

req = Request("https://www.udemy.com/")
html_page = urlopen(req)
soup = BeautifulSoup(html_page, "lxml")

# %%
# Retrieving all the URLs from the website

links = []
for link in soup.findAll('a'):
    href = link.get('href')
    links.append(href)

# %%
links
# Out:
# ['/',
#  '/courses/development/',
#  '/courses/development/web-development/',
#  '/courses/development/data-science/',
#  '/courses/development/mobile-apps/',
#  '/courses/development/programming-languages/',
#  '/courses/development/game-development/',
#  '/courses/development/databases/',
#  '/courses/development/software-testing/',
#  '/courses/development/software-engineering/',
#  '/courses/development/development-tools/',
#  '/courses/development/no-code-development/',
#  '/courses/business/',
#  '/courses/business/entrepreneurship/',
#  '/courses/business/communications/',
#  '/courses/business/management/',
#  '/courses/business/sales/',
#  '/courses/business/strategy/',
#  '/courses/business/operations/',
#  '/courses/business/project-management/',
#  '/courses/business/business-law/',
#  '/courses/business/analytics-and-intelligence/',
#  '/courses/business/human-resources/',
#  '/courses/business/industry/',
#  '/courses/business/e-commerce/',
#  '/courses/business/media/',
#  '/courses/business/real-estate/',
#  '/courses/business/other-business/',
#  '/courses/finance-and-accounting/',
#  '/courses/finance-and-accounting/accounting-bookkeeping/',
#  '/courses/finance-and-accounting/compliance/',
#  '/courses/finance-and-accounting/cryptocurrency-and-blockchain/',
#  '/courses/finance-and-accounting/economics/',
#  '/courses/finance-and-accounting/finance-management/',
#  '/courses/finance-and-accounting/finance-certification-and-exam-prep/',
#  '/courses/finance-and-accounting/financial-modeling-and-analysis/',
#  '/courses/finance-and-accounting/investing-and-trading/',
#  '/courses/finance-and-accounting/money-management-tools/',
#  '/courses/finance-and-accounting/taxes/',
#  '/courses/finance-and-accounting/other-finance-and-accounting/',
#  '/courses/it-and-software/',
#  '/courses/it-and-software/it-certification/',
#  '/courses/it-and-software/network-and-security/',
#  '/courses/it-and-software/hardware/',
#  '/courses/it-and-software/operating-systems/',
#  '/courses/it-and-software/other-it-and-software/',
#  '/courses/office-productivity/',
#  '/courses/office-productivity/microsoft/',
#  '/courses/office-productivity/apple/',
#  '/courses/office-productivity/google/',
#  '/courses/office-productivity/sap/',
#  '/courses/office-productivity/oracle/',
#  '/courses/office-productivity/other-productivity/',
#  '/courses/personal-development/',
#  '/courses/personal-development/personal-transformation/',
#  '/courses/personal-development/productivity/',
#  '/courses/personal-development/leadership/',
#  '/courses/personal-development/career-development/',
#  '/courses/personal-development/parenting-and-relationships/',
#  '/courses/personal-development/happiness/',
#  '/courses/lifestyle/esoteric-practices/',
#  '/courses/personal-development/religion-and-spirituality/',
#  '/courses/personal-development/personal-brand-building/',
#  '/courses/personal-development/creativity/',
#  '/courses/personal-development/influence/',
#  '/courses/personal-development/self-esteem-and-confidence/',
#  '/courses/personal-development/stress-management/',
#  '/courses/personal-development/memory/',
#  '/courses/personal-development/motivation/',
#  '/courses/personal-development/other-personal-development/',
#  '/courses/design/',
#  '/courses/design/web-design/',
#  '/courses/design/graphic-design-and-illustration/',
#  '/courses/design/design-tools/',
#  '/courses/design/user-experience/',
#  '/courses/design/game-design/',
#  '/courses/design/3d-and-animation/',
#  '/courses/design/fashion/',
#  '/courses/design/architectural-design/',
#  '/courses/design/interior-design/',
#  '/courses/design/other-design/',
#  '/courses/marketing/',
#  '/courses/marketing/digital-marketing/',
#  '/courses/marketing/search-engine-optimization/',
#  '/courses/marketing/social-media-marketing/',
#  '/courses/marketing/branding/',
#  '/courses/marketing/marketing-fundamentals/',
#  '/courses/marketing/analytics-and-automation/',
#  '/courses/marketing/public-relations/',
#  '/courses/marketing/advertising/',
#  '/courses/marketing/video-and-mobile-marketing/',
#  '/courses/marketing/content-marketing/',
#  '/courses/marketing/growth-hacking/',
#  '/courses/marketing/affiliate-marketing/',
#  '/courses/marketing/product-marketing/',
#  '/courses/marketing/other-marketing/',
#  '/courses/lifestyle/',
#  '/courses/lifestyle/arts-and-crafts/',
#  '/courses/lifestyle/beauty-and-makeup/',
#  '/courses/lifestyle/esoteric-practices/',
#  '/courses/lifestyle/food-and-beverage/',
#  '/courses/lifestyle/gaming/',
#  '/courses/lifestyle/home-improvement/',
#  '/courses/lifestyle/pet-care-and-training/',
#  '/courses/lifestyle/travel/',
#  '/courses/lifestyle/other-lifestyle/',
#  '/courses/photography-and-video/',
#  '/courses/photography-and-video/digital-photography/',
#  '/courses/photography-and-video/photography-fundamentals/',
#  '/courses/photography-and-video/portraits/',
#  '/courses/photography-and-video/photography-tools/',
#  '/courses/photography-and-video/commercial-photography/',
#  '/courses/photography-and-video/video-design/',
#  '/courses/photography-and-video/other-photography-and-video/',
#  '/courses/health-and-fitness/',
#  '/courses/health-and-fitness/fitness/',
#  '/courses/health-and-fitness/general-health/',
#  '/courses/health-and-fitness/sports/',
#  '/courses/health-and-fitness/nutrition/',
#  '/courses/health-and-fitness/yoga/',
#  '/courses/health-and-fitness/mental-health/',
#  '/courses/health-and-fitness/self-defense/',
#  '/courses/health-and-fitness/safety-and-first-aid/',
#  '/courses/health-and-fitness/dance/',
#  '/courses/health-and-fitness/meditation/',
#  '/courses/health-and-fitness/other-health-and-fitness/',
#  '/courses/music/',
#  '/courses/music/instruments/',
#  '/courses/music/production/',
#  '/courses/music/music-fundamentals/',
#  '/courses/music/vocal/',
#  '/courses/music/music-techniques/',
#  '/courses/music/music-software/',
#  '/courses/music/other-music/',
#  '/courses/teaching-and-academics/',
#  '/courses/teaching-and-academics/engineering/',
#  '/courses/teaching-and-academics/humanities/',
#  '/courses/teaching-and-academics/math/',
#  '/courses/teaching-and-academics/science/',
#  '/courses/teaching-and-academics/online-education/',
#  '/courses/teaching-and-academics/social-science/',
#  '/courses/teaching-and-academics/language/',
#  '/courses/teaching-and-academics/teacher-training/',
#  '/courses/teaching-and-academics/test-prep/',
#  '/courses/teaching-and-academics/other-teaching-academics/',
#  '/topic/web-development/',
#  '/topic/javascript/',
#  '/topic/react/',
#  '/topic/css/',
#  '/topic/angular/',
#  '/topic/nodejs/',
#  '/topic/typescript/',
#  '/topic/html5/',
#  '/topic/php/',
#  '/topic/aws-certification/',
#  '/topic/microsoft-certification/',
#  '/topic/aws-certified-solutions-architect-associate/',
#  '/topic/aws-certified-cloud-practitioner/',
#  '/topic/comptia-a/',
#  '/topic/amazon-aws/',
#  '/topic/cisco-ccna/',
#  '/topic/comptia-security/',
#  '/topic/aws-certified-developer-associate/',
#  '/topic/microsoft-power-bi/',
#  '/topic/sql/',
#  '/topic/business-analysis/',
#  '/topic/data-modeling/',
#  '/topic/tableau/',
#  '/topic/data-analysis/',
#  '/topic/data-cleaning/',
#  '/topic/data-warehouse/',
#  '/topic/statistics/',
#  '/topic/unity/',
#  '/topic/unreal-engine/',
#  '/topic/game-development/',
#  '/topic/c-sharp/',
#  '/topic/3d-game-development/',
#  '/topic/c-plus-plus/',
#  '/topic/2d-game-development/',
#  '/topic/unreal-engine-blueprints/',
#  '/topic/blender/',
#  '/topic/google-flutter/',
#  '/topic/ios-development/',
#  '/topic/android-development/',
#  '/topic/react-native/',
#  '/topic/swift/',
#  '/topic/dart-programming-language/',
#  '/topic/kotlin/',
#  '/topic/swiftui/',
#  '/topic/mobile-development/',
#  '/topic/graphic-design/',
#  '/topic/photoshop/',
#  '/topic/adobe-illustrator/',
#  '/topic/drawing/',
#  '/topic/canva/',
#  '/topic/digital-painting/',
#  '/topic/procreate-ipad-app/',
#  '/topic/design-theory/',
#  '/topic/indesign/',
#  '/topic/life-coaching/',
#  '/topic/personal-development/',
#  '/topic/neuro-linguistic-programming/',
#  '/topic/personal-transformation/',
#  '/topic/mindfulness/',
#  '/topic/sound-therapy/',
#  '/topic/life-purpose/',
#  '/topic/coaching/',
#  '/topic/emotional-intelligence/',
#  '/topic/business-fundamentals/',
#  '/topic/entrepreneurship/',
#  '/topic/freelancing/',
#  '/topic/business-strategy/',
#  '/topic/online-business/',
#  '/topic/startup/',
#  '/topic/business-plan/',
#  '/topic/blogging/',
#  '/topic/home-business/',
#  '/topic/digital-marketing/',
#  '/topic/social-media-marketing/',
#  '/topic/marketing-strategy/',
#  '/topic/copywriting/',
#  '/topic/internet-marketing/',
#  '/topic/startup/',
#  '/topic/google-analytics/',
#  '/topic/email-marketing/',
#  '/topic/youtube-marketing/',
#  'https://about.udemy.com/new-years-bonus/',
#  'https://about.udemy.com/new-years-bonus/?locale=en_US',
#  '/courses/design/',
#  '/courses/development/',
#  '/courses/marketing/',
#  '/courses/it-and-software/',
#  '/courses/personal-development/',
#  '/courses/business/',
#  '/courses/photography/',
#  '/courses/music/',
#  '/courses/design/',
#  '/courses/development/',
#  '/courses/marketing/',
#  '/courses/it-and-software/',
#  '/courses/personal-development/',
#  '/courses/business/',
#  '/courses/photography/',
#  '/courses/music/',
#  '/topic/python/',
#  '/topic/web-development/',
#  '/topic/machine-learning/',
#  '/topic/financial-analysis/',
#  '/topic/sql/',
#  '/topic/pmp/',
#  '/topic/aws-certification/',
#  '/topic/ethical-hacking/',
#  '/topic/cyber-security/',
#  '/topic/photoshop/',
#  '/topic/graphic-design/',
#  '/topic/drawing/',
#  '/featured-topics/',
#  'https://www.udemy.com/teaching/?ref=teach_home-body',
#  '/udemy-business/request-demo-mx/?ref=ufb_home-body&utm_type=mx&utm_method=0&user_type=visitor&locale=en_US',
#  'https://about.udemy.com/tag/stories/',
#  '/udemy-business/?locale=en_US&mx_pg=home-page&path=%2F&ref=footer',
#  '/teaching/?ref=teach_footer',
#  '/mobile/',
#  'https://about.udemy.com/?locale=en-us',
#  'https://about.udemy.com/company?locale=en-us#offices',
#  'https://about.udemy.com/careers?locale=en-us',
#  'https://blog.udemy.com/?ref=footer',
#  '/support/',
#  '/affiliate/',
#  'https://investors.udemy.com',
#  '/terms/',
#  '/terms/privacy/',
#  '/sitemap/',
#  'https://about.udemy.com/accessibility-statement?locale=en-us',
#  '/']

# %% [markdown]
# Observations:
#
# 1) Issue: There were some URLs having only / <br>
# Solution: Such URLs actually represent the home page i.e. Base URL, so these URLs must be removed from the list, and only one base URL must be added to the list
#
# 2) Issue: Some URLs have certain arguments with use of ? <br>
# Solution: URLs must be cleaned, with no ? symbols, remove the latter part after ?, just keep the actual valid URLs
#
# 3) Issue: Most of the URLs don't have a domain starting with https://www.udemy.com <br>
# Solution: Domain needs to be added for such URLs
#
# 4) Issue: Some URLs don't have a ending / <br>
# Solution: / needs to be added at the end of such URLs
#
# 5) Issue: There may be duplicate URLs acquired while scraping <br>
# Solution: Duplicate URLs must be removed
#
# 6) Issue: The URLs must be of the same domain as www.udemy.com, some URLs have their domain as about.udemy.com <br>
# Solution: Such URLs must be removed
#
# 7) Issue: Udemy has its own sitemap, and we have obtained that link as well while scraping URLs <br>
# Solution: The URL indicating Udemy sitemap must be removed

# %% [markdown]
# #### <font color="green">Why these observations were made, what is the use of this preprocessing in Sitemap:</font>
#
# For an entry to be included in \<loc> tag, <br>
#
# 1) It must be a valid URL that starts with http or https and should have a proper domain, which covers Issues 1 and 3. <br>All the URLs of a specific sitemap must have the same domain as that of the sitemap. Like if sitemap is located on "https://www.abc.com/sitemap.xml", then URL entries contained in that sitemap must have their domain as "https://wwww.abc.com/ " which is issue 6. <br>So for handling all these issues, we have prepended BASE_URL i.e. Udemy domain. Also URLs that already have some domain other than BASE_URL are removed as these don't match the same domain.
#
# 2) The URL must have a trailing slash, which is our issue 4 and it should have no arguments, which covers our issue 2. So we have added a trailing slash to URLs and removed the arguments (? part in URL).
#
# 3) We need unique URL entries for a sitemap, which handles issue 5. Udemy has its own sitemap entry, and we don't include sitemap entry in a sitemap. So the URL conatining sitemap entry is removed, which solves our issue 7.

# %%
BASE_URL = 'https://www.udemy.com'

# %% [markdown]
# #### Pre-processing of URL Links

# %%
def preprocessURLs(links):
    """
    As per the observations and solutions discussed, this method is used for preprocessing of URLs.
    It will take URL Links as input, and output valid URLs that can be included in sitemap.
    """
    
    Urls = []

    for link in links:
        processed_link = link
    
        # Check for valid URL starting with https://
        if not processed_link.startswith("https://"):
            # Check for starting /
            if not processed_link.startswith("/"):
                processed_link = "/" + processed_link
            processed_link = BASE_URL + processed_link
        
        # Check for ? arguments
        if "?" in processed_link:
            processed_link = processed_link.split("?")[0]
        
        # Check for ending /
        if not processed_link.endswith("/"):
            processed_link = processed_link + "/"
        
        # Check for duplicate URLs
        if processed_link not in Urls and (processed_link.startswith(BASE_URL) and (not processed_link=='https://www.udemy.com/sitemap/')):
            Urls.append(processed_link)
            
    return Urls

# %%
Urls = preprocessURLs(links)
Urls
# Out:
# ['https://www.udemy.com/',
#  'https://www.udemy.com/courses/development/',
#  'https://www.udemy.com/courses/development/web-development/',
#  'https://www.udemy.com/courses/development/data-science/',
#  'https://www.udemy.com/courses/development/mobile-apps/',
#  'https://www.udemy.com/courses/development/programming-languages/',
#  'https://www.udemy.com/courses/development/game-development/',
#  'https://www.udemy.com/courses/development/databases/',
#  'https://www.udemy.com/courses/development/software-testing/',
#  'https://www.udemy.com/courses/development/software-engineering/',
#  'https://www.udemy.com/courses/development/development-tools/',
#  'https://www.udemy.com/courses/development/no-code-development/',
#  'https://www.udemy.com/courses/business/',
#  'https://www.udemy.com/courses/business/entrepreneurship/',
#  'https://www.udemy.com/courses/business/communications/',
#  'https://www.udemy.com/courses/business/management/',
#  'https://www.udemy.com/courses/business/sales/',
#  'https://www.udemy.com/courses/business/strategy/',
#  'https://www.udemy.com/courses/business/operations/',
#  'https://www.udemy.com/courses/business/project-management/',
#  'https://www.udemy.com/courses/business/business-law/',
#  'https://www.udemy.com/courses/business/analytics-and-intelligence/',
#  'https://www.udemy.com/courses/business/human-resources/',
#  'https://www.udemy.com/courses/business/industry/',
#  'https://www.udemy.com/courses/business/e-commerce/',
#  'https://www.udemy.com/courses/business/media/',
#  'https://www.udemy.com/courses/business/real-estate/',
#  'https://www.udemy.com/courses/business/other-business/',
#  'https://www.udemy.com/courses/finance-and-accounting/',
#  'https://www.udemy.com/courses/finance-and-accounting/accounting-bookkeeping/',
#  'https://www.udemy.com/courses/finance-and-accounting/compliance/',
#  'https://www.udemy.com/courses/finance-and-accounting/cryptocurrency-and-blockchain/',
#  'https://www.udemy.com/courses/finance-and-accounting/economics/',
#  'https://www.udemy.com/courses/finance-and-accounting/finance-management/',
#  'https://www.udemy.com/courses/finance-and-accounting/finance-certification-and-exam-prep/',
#  'https://www.udemy.com/courses/finance-and-accounting/financial-modeling-and-analysis/',
#  'https://www.udemy.com/courses/finance-and-accounting/investing-and-trading/',
#  'https://www.udemy.com/courses/finance-and-accounting/money-management-tools/',
#  'https://www.udemy.com/courses/finance-and-accounting/taxes/',
#  'https://www.udemy.com/courses/finance-and-accounting/other-finance-and-accounting/',
#  'https://www.udemy.com/courses/it-and-software/',
#  'https://www.udemy.com/courses/it-and-software/it-certification/',
#  'https://www.udemy.com/courses/it-and-software/network-and-security/',
#  'https://www.udemy.com/courses/it-and-software/hardware/',
#  'https://www.udemy.com/courses/it-and-software/operating-systems/',
#  'https://www.udemy.com/courses/it-and-software/other-it-and-software/',
#  'https://www.udemy.com/courses/office-productivity/',
#  'https://www.udemy.com/courses/office-productivity/microsoft/',
#  'https://www.udemy.com/courses/office-productivity/apple/',
#  'https://www.udemy.com/courses/office-productivity/google/',
#  'https://www.udemy.com/courses/office-productivity/sap/',
#  'https://www.udemy.com/courses/office-productivity/oracle/',
#  'https://www.udemy.com/courses/office-productivity/other-productivity/',
#  'https://www.udemy.com/courses/personal-development/',
#  'https://www.udemy.com/courses/personal-development/personal-transformation/',
#  'https://www.udemy.com/courses/personal-development/productivity/',
#  'https://www.udemy.com/courses/personal-development/leadership/',
#  'https://www.udemy.com/courses/personal-development/career-development/',
#  'https://www.udemy.com/courses/personal-development/parenting-and-relationships/',
#  'https://www.udemy.com/courses/personal-development/happiness/',
#  'https://www.udemy.com/courses/lifestyle/esoteric-practices/',
#  'https://www.udemy.com/courses/personal-development/religion-and-spirituality/',
#  'https://www.udemy.com/courses/personal-development/personal-brand-building/',
#  'https://www.udemy.com/courses/personal-development/creativity/',
#  'https://www.udemy.com/courses/personal-development/influence/',
#  'https://www.udemy.com/courses/personal-development/self-esteem-and-confidence/',
#  'https://www.udemy.com/courses/personal-development/stress-management/',
#  'https://www.udemy.com/courses/personal-development/memory/',
#  'https://www.udemy.com/courses/personal-development/motivation/',
#  'https://www.udemy.com/courses/personal-development/other-personal-development/',
#  'https://www.udemy.com/courses/design/',
#  'https://www.udemy.com/courses/design/web-design/',
#  'https://www.udemy.com/courses/design/graphic-design-and-illustration/',
#  'https://www.udemy.com/courses/design/design-tools/',
#  'https://www.udemy.com/courses/design/user-experience/',
#  'https://www.udemy.com/courses/design/game-design/',
#  'https://www.udemy.com/courses/design/3d-and-animation/',
#  'https://www.udemy.com/courses/design/fashion/',
#  'https://www.udemy.com/courses/design/architectural-design/',
#  'https://www.udemy.com/courses/design/interior-design/',
#  'https://www.udemy.com/courses/design/other-design/',
#  'https://www.udemy.com/courses/marketing/',
#  'https://www.udemy.com/courses/marketing/digital-marketing/',
#  'https://www.udemy.com/courses/marketing/search-engine-optimization/',
#  'https://www.udemy.com/courses/marketing/social-media-marketing/',
#  'https://www.udemy.com/courses/marketing/branding/',
#  'https://www.udemy.com/courses/marketing/marketing-fundamentals/',
#  'https://www.udemy.com/courses/marketing/analytics-and-automation/',
#  'https://www.udemy.com/courses/marketing/public-relations/',
#  'https://www.udemy.com/courses/marketing/advertising/',
#  'https://www.udemy.com/courses/marketing/video-and-mobile-marketing/',
#  'https://www.udemy.com/courses/marketing/content-marketing/',
#  'https://www.udemy.com/courses/marketing/growth-hacking/',
#  'https://www.udemy.com/courses/marketing/affiliate-marketing/',
#  'https://www.udemy.com/courses/marketing/product-marketing/',
#  'https://www.udemy.com/courses/marketing/other-marketing/',
#  'https://www.udemy.com/courses/lifestyle/',
#  'https://www.udemy.com/courses/lifestyle/arts-and-crafts/',
#  'https://www.udemy.com/courses/lifestyle/beauty-and-makeup/',
#  'https://www.udemy.com/courses/lifestyle/food-and-beverage/',
#  'https://www.udemy.com/courses/lifestyle/gaming/',
#  'https://www.udemy.com/courses/lifestyle/home-improvement/',
#  'https://www.udemy.com/courses/lifestyle/pet-care-and-training/',
#  'https://www.udemy.com/courses/lifestyle/travel/',
#  'https://www.udemy.com/courses/lifestyle/other-lifestyle/',
#  'https://www.udemy.com/courses/photography-and-video/',
#  'https://www.udemy.com/courses/photography-and-video/digital-photography/',
#  'https://www.udemy.com/courses/photography-and-video/photography-fundamentals/',
#  'https://www.udemy.com/courses/photography-and-video/portraits/',
#  'https://www.udemy.com/courses/photography-and-video/photography-tools/',
#  'https://www.udemy.com/courses/photography-and-video/commercial-photography/',
#  'https://www.udemy.com/courses/photography-and-video/video-design/',
#  'https://www.udemy.com/courses/photography-and-video/other-photography-and-video/',
#  'https://www.udemy.com/courses/health-and-fitness/',
#  'https://www.udemy.com/courses/health-and-fitness/fitness/',
#  'https://www.udemy.com/courses/health-and-fitness/general-health/',
#  'https://www.udemy.com/courses/health-and-fitness/sports/',
#  'https://www.udemy.com/courses/health-and-fitness/nutrition/',
#  'https://www.udemy.com/courses/health-and-fitness/yoga/',
#  'https://www.udemy.com/courses/health-and-fitness/mental-health/',
#  'https://www.udemy.com/courses/health-and-fitness/self-defense/',
#  'https://www.udemy.com/courses/health-and-fitness/safety-and-first-aid/',
#  'https://www.udemy.com/courses/health-and-fitness/dance/',
#  'https://www.udemy.com/courses/health-and-fitness/meditation/',
#  'https://www.udemy.com/courses/health-and-fitness/other-health-and-fitness/',
#  'https://www.udemy.com/courses/music/',
#  'https://www.udemy.com/courses/music/instruments/',
#  'https://www.udemy.com/courses/music/production/',
#  'https://www.udemy.com/courses/music/music-fundamentals/',
#  'https://www.udemy.com/courses/music/vocal/',
#  'https://www.udemy.com/courses/music/music-techniques/',
#  'https://www.udemy.com/courses/music/music-software/',
#  'https://www.udemy.com/courses/music/other-music/',
#  'https://www.udemy.com/courses/teaching-and-academics/',
#  'https://www.udemy.com/courses/teaching-and-academics/engineering/',
#  'https://www.udemy.com/courses/teaching-and-academics/humanities/',
#  'https://www.udemy.com/courses/teaching-and-academics/math/',
#  'https://www.udemy.com/courses/teaching-and-academics/science/',
#  'https://www.udemy.com/courses/teaching-and-academics/online-education/',
#  'https://www.udemy.com/courses/teaching-and-academics/social-science/',
#  'https://www.udemy.com/courses/teaching-and-academics/language/',
#  'https://www.udemy.com/courses/teaching-and-academics/teacher-training/',
#  'https://www.udemy.com/courses/teaching-and-academics/test-prep/',
#  'https://www.udemy.com/courses/teaching-and-academics/other-teaching-academics/',
#  'https://www.udemy.com/topic/web-development/',
#  'https://www.udemy.com/topic/javascript/',
#  'https://www.udemy.com/topic/react/',
#  'https://www.udemy.com/topic/css/',
#  'https://www.udemy.com/topic/angular/',
#  'https://www.udemy.com/topic/nodejs/',
#  'https://www.udemy.com/topic/typescript/',
#  'https://www.udemy.com/topic/html5/',
#  'https://www.udemy.com/topic/php/',
#  'https://www.udemy.com/topic/aws-certification/',
#  'https://www.udemy.com/topic/microsoft-certification/',
#  'https://www.udemy.com/topic/aws-certified-solutions-architect-associate/',
#  'https://www.udemy.com/topic/aws-certified-cloud-practitioner/',
#  'https://www.udemy.com/topic/comptia-a/',
#  'https://www.udemy.com/topic/amazon-aws/',
#  'https://www.udemy.com/topic/cisco-ccna/',
#  'https://www.udemy.com/topic/comptia-security/',
#  'https://www.udemy.com/topic/aws-certified-developer-associate/',
#  'https://www.udemy.com/topic/microsoft-power-bi/',
#  'https://www.udemy.com/topic/sql/',
#  'https://www.udemy.com/topic/business-analysis/',
#  'https://www.udemy.com/topic/data-modeling/',
#  'https://www.udemy.com/topic/tableau/',
#  'https://www.udemy.com/topic/data-analysis/',
#  'https://www.udemy.com/topic/data-cleaning/',
#  'https://www.udemy.com/topic/data-warehouse/',
#  'https://www.udemy.com/topic/statistics/',
#  'https://www.udemy.com/topic/unity/',
#  'https://www.udemy.com/topic/unreal-engine/',
#  'https://www.udemy.com/topic/game-development/',
#  'https://www.udemy.com/topic/c-sharp/',
#  'https://www.udemy.com/topic/3d-game-development/',
#  'https://www.udemy.com/topic/c-plus-plus/',
#  'https://www.udemy.com/topic/2d-game-development/',
#  'https://www.udemy.com/topic/unreal-engine-blueprints/',
#  'https://www.udemy.com/topic/blender/',
#  'https://www.udemy.com/topic/google-flutter/',
#  'https://www.udemy.com/topic/ios-development/',
#  'https://www.udemy.com/topic/android-development/',
#  'https://www.udemy.com/topic/react-native/',
#  'https://www.udemy.com/topic/swift/',
#  'https://www.udemy.com/topic/dart-programming-language/',
#  'https://www.udemy.com/topic/kotlin/',
#  'https://www.udemy.com/topic/swiftui/',
#  'https://www.udemy.com/topic/mobile-development/',
#  'https://www.udemy.com/topic/graphic-design/',
#  'https://www.udemy.com/topic/photoshop/',
#  'https://www.udemy.com/topic/adobe-illustrator/',
#  'https://www.udemy.com/topic/drawing/',
#  'https://www.udemy.com/topic/canva/',
#  'https://www.udemy.com/topic/digital-painting/',
#  'https://www.udemy.com/topic/procreate-ipad-app/',
#  'https://www.udemy.com/topic/design-theory/',
#  'https://www.udemy.com/topic/indesign/',
#  'https://www.udemy.com/topic/life-coaching/',
#  'https://www.udemy.com/topic/personal-development/',
#  'https://www.udemy.com/topic/neuro-linguistic-programming/',
#  'https://www.udemy.com/topic/personal-transformation/',
#  'https://www.udemy.com/topic/mindfulness/',
#  'https://www.udemy.com/topic/sound-therapy/',
#  'https://www.udemy.com/topic/life-purpose/',
#  'https://www.udemy.com/topic/coaching/',
#  'https://www.udemy.com/topic/emotional-intelligence/',
#  'https://www.udemy.com/topic/business-fundamentals/',
#  'https://www.udemy.com/topic/entrepreneurship/',
#  'https://www.udemy.com/topic/freelancing/',
#  'https://www.udemy.com/topic/business-strategy/',
#  'https://www.udemy.com/topic/online-business/',
#  'https://www.udemy.com/topic/startup/',
#  'https://www.udemy.com/topic/business-plan/',
#  'https://www.udemy.com/topic/blogging/',
#  'https://www.udemy.com/topic/home-business/',
#  'https://www.udemy.com/topic/digital-marketing/',
#  'https://www.udemy.com/topic/social-media-marketing/',
#  'https://www.udemy.com/topic/marketing-strategy/',
#  'https://www.udemy.com/topic/copywriting/',
#  'https://www.udemy.com/topic/internet-marketing/',
#  'https://www.udemy.com/topic/google-analytics/',
#  'https://www.udemy.com/topic/email-marketing/',
#  'https://www.udemy.com/topic/youtube-marketing/',
#  'https://www.udemy.com/courses/photography/',
#  'https://www.udemy.com/topic/python/',
#  'https://www.udemy.com/topic/machine-learning/',
#  'https://www.udemy.com/topic/financial-analysis/',
#  'https://www.udemy.com/topic/pmp/',
#  'https://www.udemy.com/topic/ethical-hacking/',
#  'https://www.udemy.com/topic/cyber-security/',
#  'https://www.udemy.com/featured-topics/',
#  'https://www.udemy.com/teaching/',
#  'https://www.udemy.com/udemy-business/request-demo-mx/',
#  'https://www.udemy.com/udemy-business/',
#  'https://www.udemy.com/mobile/',
#  'https://www.udemy.com/support/',
#  'https://www.udemy.com/affiliate/',
#  'https://www.udemy.com/terms/',
#  'https://www.udemy.com/terms/privacy/']

# %% [markdown]
# Each Sitemap must contain a maximum of 50,000 <url> tags. <br>
# And each URL from above list will become a separate <url> tag for the sitemap. <br>
# Thus we are checking the limit first, inorder to calculate number of sitemaps to generate if the URLs > 50,000. <br>
# If URLs > 50,000 they are combined into blocks of 50,000 each and the sitemaps are then constructed. We call this as 'Splitting of Sitemap'.
# And in such cases if there are multiple sitemaps (more than 1), it is better to create a Sitemap Index.

# %%
# Check for 50,000 limit, else split it in parts

def calculateNumberOfSitemaps(num_Urls):
    """
    This method calculates the number of sitemaps that can be generated, given the number of URLs as an input.
    """
    
    num_sitemaps = num_Urls // 50000
    if num_Urls % 50000 !=0:
        num_sitemaps += 1
        
        return num_sitemaps

# %%
len(Urls)
# Out:
# 240

# %%
calculateNumberOfSitemaps(len(Urls))
# Out:
# 1

# %% [markdown]
# So here, in our case the URLs are only 240, as we have only scraped the Udemy homepage. <br>
# If we had scraped more pages, we would have more unique URLs. <br>
# So here we have to create only 1 sitemap, and hence there will be no Sitemap Index

# %% [markdown]
# <font color="green">There are 2 ways to build Sitemaps and Sitemap Index:</font>
#
# <i>Method 1:</i> <br>
# The general way of including all the URLs in Sitemap and splitting sitemaps into 50,000 URL blocks each.<br>
# We have implemented this method in Part 2: Building a Combined Sitemap.
#
# <i>Method 2:</i> <br>
# Grouping each URL based on the category they belong to and creating then creating sitemaps.<br>
# Here, the number of sitemaps will depend on the number of categories and number of URLs in each category.<br>
# In usual cases, each category will have 1 sitemap considering that the URLs <=50,000.<br>
# But in case certain category has more than 50,000 URLs, that sitemap will be splitted into 2 sitemaps for that category.<br>
# We have implemented this method in Part 3: Building Category-wise Sitemap.
#
# Let's have a look at each of these methods.

# %% [markdown]
# ### PART 2: Building a Combined Sitemap

# %%
# Create method for creating sitemaps, pass file_name and Urls

def createSitemap(file_name, Urls):
    """
    This method takes file_name and Urls list as input and provides a sitemap file as an output.
    The sitemap file will be created on the current directory path.
    """
    
    root = minidom.Document()
    urlset = root.createElement('urlset')
    root.appendChild(urlset)
    urlset.setAttribute("xmlns","http://www.sitemaps.org/schemas/sitemap/0.9")
    
    for url_link in Urls:
        url = root.createElement('url')
        loc = root.createElement("loc")
        loc.appendChild(root.createTextNode(url_link))
        url.appendChild(loc)
        
        urlset.appendChild(url)
        
    xml_str = root.toprettyxml(indent="\t", encoding="UTF-8").decode("utf-8")
        
    # Writing Sitemap.xml to File
    f = open(file_name, "w")
    f.write(xml_str)
    f.close()

# %% [markdown]
# Optional tags that can be included with inside \<url> tag: \<changefreq>, \<priority>, \<lastmod> <br>
#
# Above for loop needs to be replaced with the one mentioned as follows, incase you want to add optional tags (just like we did it for \<loc> tag)<br>
# Here, in the below loop all the optional tags along with required tag \<loc> are included.<br>
# You can choose the optional tags and appropriately remove the unwanted code patches from the loop.<br>
#
#     for url_link in Urls:
#
#         url = root.createElement('url')
#         loc = root.createElement("loc")
#         loc.appendChild(root.createTextNode(url_link))
#         url.appendChild(loc)
#
#         changefreq = root.createElement("changefreq")
#         changefreq.appendChild(root.createTextNode("daily"))
#         url.appendChild(changefreq)
#
#         priority = root.createElement("priority")
#         priority.appendChild(root.createTextNode("1.0"))
#         url.appendChild(priority)
#
#         lastmod = root.createElement("lastmod")
#         lastmod.appendChild(root.createTextNode("2022-12-19"))
#         url.appendChild(lastmod)
#
#         urlset.appendChild(url)

# %%
def createCombinedSitemap():
    """
    This method first calculates the number of sitemaps to be generated, then the file name is decided.
    Later, URLs are sliced into 50,000 blocks each and the corresponding sitemap files are created using these URLs.
    This method returns all the sitemap file names as its output.
    """
    
    sitemap_file_names = []   
    num_sitemaps = calculateNumberOfSitemaps(len(Urls))
    
    sitemap_index = 0
    if num_sitemaps > 1:
        sitemap_index = 1
    
    for part_number in range(num_sitemaps):
    
        if num_sitemaps == 1:
            file_name = "sitemap.xml"
        else:
            file_name = "sitemap_" + str(part_number+1) + ".xml"
    
        min_offset = 50000 * (part_number)
        max_offset = 50000 * (part_number + 1)
        if max_offset > len(Urls):
            max_offset = len(Urls)

        Url_links = Urls[min_offset : max_offset]
        createSitemap(file_name, Url_links)
    
        if sitemap_index:
            sitemap_file_names.append(file_name)

    return sitemap_file_names

# %%
sitemap_file_names = createCombinedSitemap()

# %%
# Reading the sitemap file we just created

f = open("sitemap.xml", "r")
print(f.read())
f.close()
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9">
# 	<url>
# 		<loc>https://www.udemy.com/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/development/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/development/web-development/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/development/data-science/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/development/mobile-apps/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/development/programming-languages/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/development/game-development/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/development/databases/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/development/software-testing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/development/software-engineering/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/development/development-tools/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/development/no-code-development/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/entrepreneurship/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/communications/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/management/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/sales/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/strategy/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/operations/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/project-management/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/business-law/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/analytics-and-intelligence/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/human-resources/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/industry/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/e-commerce/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/media/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/real-estate/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/business/other-business/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/finance-and-accounting/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/finance-and-accounting/accounting-bookkeeping/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/finance-and-accounting/compliance/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/finance-and-accounting/cryptocurrency-and-blockchain/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/finance-and-accounting/economics/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/finance-and-accounting/finance-management/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/finance-and-accounting/finance-certification-and-exam-prep/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/finance-and-accounting/financial-modeling-and-analysis/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/finance-and-accounting/investing-and-trading/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/finance-and-accounting/money-management-tools/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/finance-and-accounting/taxes/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/finance-and-accounting/other-finance-and-accounting/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/it-and-software/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/it-and-software/it-certification/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/it-and-software/network-and-security/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/it-and-software/hardware/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/it-and-software/operating-systems/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/it-and-software/other-it-and-software/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/office-productivity/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/office-productivity/microsoft/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/office-productivity/apple/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/office-productivity/google/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/office-productivity/sap/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/office-productivity/oracle/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/office-productivity/other-productivity/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/personal-transformation/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/productivity/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/leadership/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/career-development/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/parenting-and-relationships/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/happiness/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/lifestyle/esoteric-practices/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/religion-and-spirituality/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/personal-brand-building/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/creativity/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/influence/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/self-esteem-and-confidence/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/stress-management/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/memory/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/motivation/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/personal-development/other-personal-development/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/design/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/design/web-design/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/design/graphic-design-and-illustration/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/design/design-tools/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/design/user-experience/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/design/game-design/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/design/3d-and-animation/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/design/fashion/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/design/architectural-design/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/design/interior-design/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/design/other-design/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/marketing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/marketing/digital-marketing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/marketing/search-engine-optimization/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/marketing/social-media-marketing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/marketing/branding/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/marketing/marketing-fundamentals/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/marketing/analytics-and-automation/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/marketing/public-relations/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/marketing/advertising/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/marketing/video-and-mobile-marketing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/marketing/content-marketing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/marketing/growth-hacking/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/marketing/affiliate-marketing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/marketing/product-marketing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/marketing/other-marketing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/lifestyle/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/lifestyle/arts-and-crafts/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/lifestyle/beauty-and-makeup/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/lifestyle/food-and-beverage/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/lifestyle/gaming/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/lifestyle/home-improvement/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/lifestyle/pet-care-and-training/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/lifestyle/travel/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/lifestyle/other-lifestyle/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/photography-and-video/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/photography-and-video/digital-photography/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/photography-and-video/photography-fundamentals/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/photography-and-video/portraits/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/photography-and-video/photography-tools/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/photography-and-video/commercial-photography/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/photography-and-video/video-design/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/photography-and-video/other-photography-and-video/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/health-and-fitness/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/health-and-fitness/fitness/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/health-and-fitness/general-health/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/health-and-fitness/sports/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/health-and-fitness/nutrition/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/health-and-fitness/yoga/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/health-and-fitness/mental-health/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/health-and-fitness/self-defense/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/health-and-fitness/safety-and-first-aid/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/health-and-fitness/dance/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/health-and-fitness/meditation/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/health-and-fitness/other-health-and-fitness/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/music/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/music/instruments/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/music/production/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/music/music-fundamentals/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/music/vocal/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/music/music-techniques/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/music/music-software/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/music/other-music/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/teaching-and-academics/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/teaching-and-academics/engineering/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/teaching-and-academics/humanities/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/teaching-and-academics/math/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/teaching-and-academics/science/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/teaching-and-academics/online-education/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/teaching-and-academics/social-science/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/teaching-and-academics/language/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/teaching-and-academics/teacher-training/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/teaching-and-academics/test-prep/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/teaching-and-academics/other-teaching-academics/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/web-development/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/javascript/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/react/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/css/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/angular/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/nodejs/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/typescript/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/html5/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/php/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/aws-certification/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/microsoft-certification/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/aws-certified-solutions-architect-associate/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/aws-certified-cloud-practitioner/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/comptia-a/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/amazon-aws/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/cisco-ccna/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/comptia-security/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/aws-certified-developer-associate/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/microsoft-power-bi/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/sql/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/business-analysis/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/data-modeling/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/tableau/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/data-analysis/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/data-cleaning/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/data-warehouse/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/statistics/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/unity/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/unreal-engine/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/game-development/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/c-sharp/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/3d-game-development/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/c-plus-plus/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/2d-game-development/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/unreal-engine-blueprints/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/blender/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/google-flutter/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/ios-development/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/android-development/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/react-native/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/swift/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/dart-programming-language/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/kotlin/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/swiftui/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/mobile-development/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/graphic-design/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/photoshop/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/adobe-illustrator/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/drawing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/canva/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/digital-painting/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/procreate-ipad-app/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/design-theory/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/indesign/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/life-coaching/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/personal-development/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/neuro-linguistic-programming/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/personal-transformation/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/mindfulness/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/sound-therapy/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/life-purpose/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/coaching/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/emotional-intelligence/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/business-fundamentals/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/entrepreneurship/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/freelancing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/business-strategy/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/online-business/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/startup/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/business-plan/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/blogging/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/home-business/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/digital-marketing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/social-media-marketing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/marketing-strategy/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/copywriting/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/internet-marketing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/google-analytics/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/email-marketing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/youtube-marketing/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/courses/photography/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/python/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/machine-learning/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/financial-analysis/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/pmp/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/ethical-hacking/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/topic/cyber-security/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/featured-topics/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/teaching/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/udemy-business/request-demo-mx/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/udemy-business/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/mobile/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/support/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/affiliate/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/terms/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/terms/privacy/</loc>
# 	</url>
# </urlset>

# %%
def createSitemapIndex(file_names):
    """
    This method takes all the sitemap file names as input and constructs a sitemap index file.
    The sitemap index file will be created on the current directory path.
    """
    
    root = minidom.Document()
    sitemap_index = root.createElement('sitemapindex')
    root.appendChild(sitemap_index)
    sitemap_index.setAttribute("xmlns","http://www.sitemaps.org/schemas/sitemap/0.9")
    
    for sitemap_file in file_names:
        sitemap = root.createElement("sitemap")
        loc = root.createElement("loc")
        loc.appendChild(root.createTextNode(BASE_URL + "/" + sitemap_file))
        sitemap.appendChild(loc)
        
        sitemap_index.appendChild(sitemap)
        
    xml_str = root.toprettyxml(indent="\t", encoding="UTF-8").decode("utf-8")
    
    f = open("sitemap_index.xml", "w")
    f.write(xml_str)
    f.close()

# %% [markdown]
# #### <font color="green">Why we are preprending BASE_URL to file names:</font>
# (BASE_URL + "/" + sitemap_file)
#
# A Sitemap file must have same domain name, just as the URL entries that are in the sitemap.<br>
# As all the URLs have BASE_URL as their domain, we have prepended BASE_URL to sitemap file name as well. <br>
# So that this sitemap file will be rendered from the same domain, even though it is stored somewhere else.

# %%
# Inorder to demostrate Sitemap Index, we will add few sample URLs to the main list so that URLs > 50,000

Urls = Urls * 250
len(Urls)
# Out:
# 60000

# %% [markdown]
# #### Why there is need to create Sitemap Index:
#
# In order to maintain record od all the sitemap files created, we create a Sitemap Index file. <br>
# A Sitemap Index consists of multiple sitemap entries, which actually resemble to sitemaps containing URLs and their information.
# A Sitemap Index can include maximum 50,000 sitemap entries and size of Sitemap Index must be less than 50 MB. There can be more than 1 Sitemap Index file.
#
#
# #### XML Tags used in Sitemap Index:
#
# Following are the available XML Tags for building a Sitemap Index:
#
# 1) \<sitemapindex> (Required Tag): This is main parent tag of the file which contains information about sitemap files. It has an attribute 'xmlns' which defines the schema of the sitemap index.
# \<sitemapindex xmlns="http://www.sitemaps.org/schemas/sitemap/0.9">
#
# 2) \<sitemap> (Required Tag): This is child tag of \<sitemapindex> and is responsible for each individual sitemap entry. Further explained tags are child tags of \<sitemap> tag.
#
# 3) \<loc> (Required Tag): This includes URL location of the sitemap. It must begin with the protocol like http or https. The Sitemap entries must be unique, there should not be any duplicates.
#
# 4) \<lastmod> (Optional Tag): This value specifies the last modified date of the corresponding sitemap file. This date should be in YYYY-MM-DD format.

# %%
sitemap_file_names = createCombinedSitemap()

if len(sitemap_file_names) > 0:
    createSitemapIndex(sitemap_file_names)

# %%
# Reading the sitemap index file that we just created

f = open("sitemap_index.xml", "r")
print(f.read())
f.close()
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <sitemapindex xmlns="http://www.sitemaps.org/schemas/sitemap/0.9">
# 	<sitemap>
# 		<loc>https://www.udemy.com/sitemap_1.xml</loc>
# 	</sitemap>
# 	<sitemap>
# 		<loc>https://www.udemy.com/sitemap_2.xml</loc>
# 	</sitemap>
# </sitemapindex>

# %% [markdown]
# ### PART 3: Building Category-wise Sitemap

# %% [markdown]
# #### <font color="green">Need for Categorizing URLs:</font>
#
# Inorder to create and maintain sitemaps depending on certain category parameter, we need to categorize URLs.<br>
# This categorizing will improve efficieny between teams of a certain organization.<br>
# Each team will maintain its own sitemap, thus channelization and distribution of work, maintainence and monitoring.<br>
# Thus, categorizing of URLs is organizing your sitemaps in a better, efficient and useful way.

# %%
# Categorizing URLs as per each category

categories = ["Course", "Topic", "Platform"]

# categoryUrls is a dictionary where category_name is the key and value is list of Urls of that category
categoryUrls = {}

# %%
# We will retireve the Udemy URLs again, as for Sitemap Index demonstration we had added dummy URLs

links = []
for link in soup.findAll('a'):
    href = link.get('href')
    links.append(href)
    
Urls = preprocessURLs(links)

# %%
len(Urls)
# Out:
# 240

# %% [markdown]
# Here, depending on the patterns in URL links, we will categorize them into 3 categories.<br>
# This categorization purely depends on business requirements. And the categories should be pre-decided / chosen by the business team, as required.
#
# Pattern-wise Categorization used in our case:<br>
#
# 1) Course: URLs having /courses/ or /course/ in their URL path will be categorized into Course category.<br>
# 2) Topic: URLs having /topic/ in their URL path will have Topic as their category.<br>
# 3) Platform: URLs that include no such pattern are more likely to be platform URLs.

# %%
for url_link in Urls:
    if ('/course/' in url_link) or ('/courses/' in url_link):
        courseUrls = []
        if 'Course' in categoryUrls:
            courseUrls = categoryUrls['Course']
        courseUrls.append(url_link)
        categoryUrls['Course'] = courseUrls
    
    elif ('/topic/' in url_link):
        topicUrls = []
        if 'Topic' in categoryUrls:
            topicUrls = categoryUrls['Topic']
        topicUrls.append(url_link)
        categoryUrls['Topic'] = topicUrls
    
    else:
        platformUrls = []
        if 'Platform' in categoryUrls:
            platformUrls = categoryUrls['Platform']
        platformUrls.append(url_link)
        categoryUrls['Platform'] = platformUrls

# %%
categoryUrls
# Out:
# {'Platform': ['https://www.udemy.com/',
#   'https://www.udemy.com/featured-topics/',
#   'https://www.udemy.com/teaching/',
#   'https://www.udemy.com/udemy-business/request-demo-mx/',
#   'https://www.udemy.com/udemy-business/',
#   'https://www.udemy.com/mobile/',
#   'https://www.udemy.com/support/',
#   'https://www.udemy.com/affiliate/',
#   'https://www.udemy.com/terms/',
#   'https://www.udemy.com/terms/privacy/'],
#  'Course': ['https://www.udemy.com/courses/development/',
#   'https://www.udemy.com/courses/development/web-development/',
#   'https://www.udemy.com/courses/development/data-science/',
#   'https://www.udemy.com/courses/development/mobile-apps/',
#   'https://www.udemy.com/courses/development/programming-languages/',
#   'https://www.udemy.com/courses/development/game-development/',
#   'https://www.udemy.com/courses/development/databases/',
#   'https://www.udemy.com/courses/development/software-testing/',
#   'https://www.udemy.com/courses/development/software-engineering/',
#   'https://www.udemy.com/courses/development/development-tools/',
#   'https://www.udemy.com/courses/development/no-code-development/',
#   'https://www.udemy.com/courses/business/',
#   'https://www.udemy.com/courses/business/entrepreneurship/',
#   'https://www.udemy.com/courses/business/communications/',
#   'https://www.udemy.com/courses/business/management/',
#   'https://www.udemy.com/courses/business/sales/',
#   'https://www.udemy.com/courses/business/strategy/',
#   'https://www.udemy.com/courses/business/operations/',
#   'https://www.udemy.com/courses/business/project-management/',
#   'https://www.udemy.com/courses/business/business-law/',
#   'https://www.udemy.com/courses/business/analytics-and-intelligence/',
#   'https://www.udemy.com/courses/business/human-resources/',
#   'https://www.udemy.com/courses/business/industry/',
#   'https://www.udemy.com/courses/business/e-commerce/',
#   'https://www.udemy.com/courses/business/media/',
#   'https://www.udemy.com/courses/business/real-estate/',
#   'https://www.udemy.com/courses/business/other-business/',
#   'https://www.udemy.com/courses/finance-and-accounting/',
#   'https://www.udemy.com/courses/finance-and-accounting/accounting-bookkeeping/',
#   'https://www.udemy.com/courses/finance-and-accounting/compliance/',
#   'https://www.udemy.com/courses/finance-and-accounting/cryptocurrency-and-blockchain/',
#   'https://www.udemy.com/courses/finance-and-accounting/economics/',
#   'https://www.udemy.com/courses/finance-and-accounting/finance-management/',
#   'https://www.udemy.com/courses/finance-and-accounting/finance-certification-and-exam-prep/',
#   'https://www.udemy.com/courses/finance-and-accounting/financial-modeling-and-analysis/',
#   'https://www.udemy.com/courses/finance-and-accounting/investing-and-trading/',
#   'https://www.udemy.com/courses/finance-and-accounting/money-management-tools/',
#   'https://www.udemy.com/courses/finance-and-accounting/taxes/',
#   'https://www.udemy.com/courses/finance-and-accounting/other-finance-and-accounting/',
#   'https://www.udemy.com/courses/it-and-software/',
#   'https://www.udemy.com/courses/it-and-software/it-certification/',
#   'https://www.udemy.com/courses/it-and-software/network-and-security/',
#   'https://www.udemy.com/courses/it-and-software/hardware/',
#   'https://www.udemy.com/courses/it-and-software/operating-systems/',
#   'https://www.udemy.com/courses/it-and-software/other-it-and-software/',
#   'https://www.udemy.com/courses/office-productivity/',
#   'https://www.udemy.com/courses/office-productivity/microsoft/',
#   'https://www.udemy.com/courses/office-productivity/apple/',
#   'https://www.udemy.com/courses/office-productivity/google/',
#   'https://www.udemy.com/courses/office-productivity/sap/',
#   'https://www.udemy.com/courses/office-productivity/oracle/',
#   'https://www.udemy.com/courses/office-productivity/other-productivity/',
#   'https://www.udemy.com/courses/personal-development/',
#   'https://www.udemy.com/courses/personal-development/personal-transformation/',
#   'https://www.udemy.com/courses/personal-development/productivity/',
#   'https://www.udemy.com/courses/personal-development/leadership/',
#   'https://www.udemy.com/courses/personal-development/career-development/',
#   'https://www.udemy.com/courses/personal-development/parenting-and-relationships/',
#   'https://www.udemy.com/courses/personal-development/happiness/',
#   'https://www.udemy.com/courses/lifestyle/esoteric-practices/',
#   'https://www.udemy.com/courses/personal-development/religion-and-spirituality/',
#   'https://www.udemy.com/courses/personal-development/personal-brand-building/',
#   'https://www.udemy.com/courses/personal-development/creativity/',
#   'https://www.udemy.com/courses/personal-development/influence/',
#   'https://www.udemy.com/courses/personal-development/self-esteem-and-confidence/',
#   'https://www.udemy.com/courses/personal-development/stress-management/',
#   'https://www.udemy.com/courses/personal-development/memory/',
#   'https://www.udemy.com/courses/personal-development/motivation/',
#   'https://www.udemy.com/courses/personal-development/other-personal-development/',
#   'https://www.udemy.com/courses/design/',
#   'https://www.udemy.com/courses/design/web-design/',
#   'https://www.udemy.com/courses/design/graphic-design-and-illustration/',
#   'https://www.udemy.com/courses/design/design-tools/',
#   'https://www.udemy.com/courses/design/user-experience/',
#   'https://www.udemy.com/courses/design/game-design/',
#   'https://www.udemy.com/courses/design/3d-and-animation/',
#   'https://www.udemy.com/courses/design/fashion/',
#   'https://www.udemy.com/courses/design/architectural-design/',
#   'https://www.udemy.com/courses/design/interior-design/',
#   'https://www.udemy.com/courses/design/other-design/',
#   'https://www.udemy.com/courses/marketing/',
#   'https://www.udemy.com/courses/marketing/digital-marketing/',
#   'https://www.udemy.com/courses/marketing/search-engine-optimization/',
#   'https://www.udemy.com/courses/marketing/social-media-marketing/',
#   'https://www.udemy.com/courses/marketing/branding/',
#   'https://www.udemy.com/courses/marketing/marketing-fundamentals/',
#   'https://www.udemy.com/courses/marketing/analytics-and-automation/',
#   'https://www.udemy.com/courses/marketing/public-relations/',
#   'https://www.udemy.com/courses/marketing/advertising/',
#   'https://www.udemy.com/courses/marketing/video-and-mobile-marketing/',
#   'https://www.udemy.com/courses/marketing/content-marketing/',
#   'https://www.udemy.com/courses/marketing/growth-hacking/',
#   'https://www.udemy.com/courses/marketing/affiliate-marketing/',
#   'https://www.udemy.com/courses/marketing/product-marketing/',
#   'https://www.udemy.com/courses/marketing/other-marketing/',
#   'https://www.udemy.com/courses/lifestyle/',
#   'https://www.udemy.com/courses/lifestyle/arts-and-crafts/',
#   'https://www.udemy.com/courses/lifestyle/beauty-and-makeup/',
#   'https://www.udemy.com/courses/lifestyle/food-and-beverage/',
#   'https://www.udemy.com/courses/lifestyle/gaming/',
#   'https://www.udemy.com/courses/lifestyle/home-improvement/',
#   'https://www.udemy.com/courses/lifestyle/pet-care-and-training/',
#   'https://www.udemy.com/courses/lifestyle/travel/',
#   'https://www.udemy.com/courses/lifestyle/other-lifestyle/',
#   'https://www.udemy.com/courses/photography-and-video/',
#   'https://www.udemy.com/courses/photography-and-video/digital-photography/',
#   'https://www.udemy.com/courses/photography-and-video/photography-fundamentals/',
#   'https://www.udemy.com/courses/photography-and-video/portraits/',
#   'https://www.udemy.com/courses/photography-and-video/photography-tools/',
#   'https://www.udemy.com/courses/photography-and-video/commercial-photography/',
#   'https://www.udemy.com/courses/photography-and-video/video-design/',
#   'https://www.udemy.com/courses/photography-and-video/other-photography-and-video/',
#   'https://www.udemy.com/courses/health-and-fitness/',
#   'https://www.udemy.com/courses/health-and-fitness/fitness/',
#   'https://www.udemy.com/courses/health-and-fitness/general-health/',
#   'https://www.udemy.com/courses/health-and-fitness/sports/',
#   'https://www.udemy.com/courses/health-and-fitness/nutrition/',
#   'https://www.udemy.com/courses/health-and-fitness/yoga/',
#   'https://www.udemy.com/courses/health-and-fitness/mental-health/',
#   'https://www.udemy.com/courses/health-and-fitness/self-defense/',
#   'https://www.udemy.com/courses/health-and-fitness/safety-and-first-aid/',
#   'https://www.udemy.com/courses/health-and-fitness/dance/',
#   'https://www.udemy.com/courses/health-and-fitness/meditation/',
#   'https://www.udemy.com/courses/health-and-fitness/other-health-and-fitness/',
#   'https://www.udemy.com/courses/music/',
#   'https://www.udemy.com/courses/music/instruments/',
#   'https://www.udemy.com/courses/music/production/',
#   'https://www.udemy.com/courses/music/music-fundamentals/',
#   'https://www.udemy.com/courses/music/vocal/',
#   'https://www.udemy.com/courses/music/music-techniques/',
#   'https://www.udemy.com/courses/music/music-software/',
#   'https://www.udemy.com/courses/music/other-music/',
#   'https://www.udemy.com/courses/teaching-and-academics/',
#   'https://www.udemy.com/courses/teaching-and-academics/engineering/',
#   'https://www.udemy.com/courses/teaching-and-academics/humanities/',
#   'https://www.udemy.com/courses/teaching-and-academics/math/',
#   'https://www.udemy.com/courses/teaching-and-academics/science/',
#   'https://www.udemy.com/courses/teaching-and-academics/online-education/',
#   'https://www.udemy.com/courses/teaching-and-academics/social-science/',
#   'https://www.udemy.com/courses/teaching-and-academics/language/',
#   'https://www.udemy.com/courses/teaching-and-academics/teacher-training/',
#   'https://www.udemy.com/courses/teaching-and-academics/test-prep/',
#   'https://www.udemy.com/courses/teaching-and-academics/other-teaching-academics/',
#   'https://www.udemy.com/courses/photography/'],
#  'Topic': ['https://www.udemy.com/topic/web-development/',
#   'https://www.udemy.com/topic/javascript/',
#   'https://www.udemy.com/topic/react/',
#   'https://www.udemy.com/topic/css/',
#   'https://www.udemy.com/topic/angular/',
#   'https://www.udemy.com/topic/nodejs/',
#   'https://www.udemy.com/topic/typescript/',
#   'https://www.udemy.com/topic/html5/',
#   'https://www.udemy.com/topic/php/',
#   'https://www.udemy.com/topic/aws-certification/',
#   'https://www.udemy.com/topic/microsoft-certification/',
#   'https://www.udemy.com/topic/aws-certified-solutions-architect-associate/',
#   'https://www.udemy.com/topic/aws-certified-cloud-practitioner/',
#   'https://www.udemy.com/topic/comptia-a/',
#   'https://www.udemy.com/topic/amazon-aws/',
#   'https://www.udemy.com/topic/cisco-ccna/',
#   'https://www.udemy.com/topic/comptia-security/',
#   'https://www.udemy.com/topic/aws-certified-developer-associate/',
#   'https://www.udemy.com/topic/microsoft-power-bi/',
#   'https://www.udemy.com/topic/sql/',
#   'https://www.udemy.com/topic/business-analysis/',
#   'https://www.udemy.com/topic/data-modeling/',
#   'https://www.udemy.com/topic/tableau/',
#   'https://www.udemy.com/topic/data-analysis/',
#   'https://www.udemy.com/topic/data-cleaning/',
#   'https://www.udemy.com/topic/data-warehouse/',
#   'https://www.udemy.com/topic/statistics/',
#   'https://www.udemy.com/topic/unity/',
#   'https://www.udemy.com/topic/unreal-engine/',
#   'https://www.udemy.com/topic/game-development/',
#   'https://www.udemy.com/topic/c-sharp/',
#   'https://www.udemy.com/topic/3d-game-development/',
#   'https://www.udemy.com/topic/c-plus-plus/',
#   'https://www.udemy.com/topic/2d-game-development/',
#   'https://www.udemy.com/topic/unreal-engine-blueprints/',
#   'https://www.udemy.com/topic/blender/',
#   'https://www.udemy.com/topic/google-flutter/',
#   'https://www.udemy.com/topic/ios-development/',
#   'https://www.udemy.com/topic/android-development/',
#   'https://www.udemy.com/topic/react-native/',
#   'https://www.udemy.com/topic/swift/',
#   'https://www.udemy.com/topic/dart-programming-language/',
#   'https://www.udemy.com/topic/kotlin/',
#   'https://www.udemy.com/topic/swiftui/',
#   'https://www.udemy.com/topic/mobile-development/',
#   'https://www.udemy.com/topic/graphic-design/',
#   'https://www.udemy.com/topic/photoshop/',
#   'https://www.udemy.com/topic/adobe-illustrator/',
#   'https://www.udemy.com/topic/drawing/',
#   'https://www.udemy.com/topic/canva/',
#   'https://www.udemy.com/topic/digital-painting/',
#   'https://www.udemy.com/topic/procreate-ipad-app/',
#   'https://www.udemy.com/topic/design-theory/',
#   'https://www.udemy.com/topic/indesign/',
#   'https://www.udemy.com/topic/life-coaching/',
#   'https://www.udemy.com/topic/personal-development/',
#   'https://www.udemy.com/topic/neuro-linguistic-programming/',
#   'https://www.udemy.com/topic/personal-transformation/',
#   'https://www.udemy.com/topic/mindfulness/',
#   'https://www.udemy.com/topic/sound-therapy/',
#   'https://www.udemy.com/topic/life-purpose/',
#   'https://www.udemy.com/topic/coaching/',
#   'https://www.udemy.com/topic/emotional-intelligence/',
#   'https://www.udemy.com/topic/business-fundamentals/',
#   'https://www.udemy.com/topic/entrepreneurship/',
#   'https://www.udemy.com/topic/freelancing/',
#   'https://www.udemy.com/topic/business-strategy/',
#   'https://www.udemy.com/topic/online-business/',
#   'https://www.udemy.com/topic/startup/',
#   'https://www.udemy.com/topic/business-plan/',
#   'https://www.udemy.com/topic/blogging/',
#   'https://www.udemy.com/topic/home-business/',
#   'https://www.udemy.com/topic/digital-marketing/',
#   'https://www.udemy.com/topic/social-media-marketing/',
#   'https://www.udemy.com/topic/marketing-strategy/',
#   'https://www.udemy.com/topic/copywriting/',
#   'https://www.udemy.com/topic/internet-marketing/',
#   'https://www.udemy.com/topic/google-analytics/',
#   'https://www.udemy.com/topic/email-marketing/',
#   'https://www.udemy.com/topic/youtube-marketing/',
#   'https://www.udemy.com/topic/python/',
#   'https://www.udemy.com/topic/machine-learning/',
#   'https://www.udemy.com/topic/financial-analysis/',
#   'https://www.udemy.com/topic/pmp/',
#   'https://www.udemy.com/topic/ethical-hacking/',
#   'https://www.udemy.com/topic/cyber-security/']}

# %%
# Getting count of URLs for each category, inorder to tally with the sitemaps later

for category in categoryUrls:
    value = categoryUrls[category]
    print(category,": ",len(value))
# Out:
# Platform :  10
# Course :  144
# Topic :  86

# %%
def buildCategorySitemap(category_name, Urls, partition_number, consider_partition_number):
    """
    This method takes following arguments as its input:
    category_name: Category to which the URLs belong to
    Urls: List of URLs of having Category category_name (Here Categpry wil be Platform/Topic/Course)
    partition_number: Part Number of the sitemap to be generated.
                      If category has more than 50,000 URLs, multiple sitemaps will be generated for that category.
                      This parameter tells which sitemap needs to be generated out of all the multiple sitemaps.
    consider_partition_number: It indicates whether to include partition_number in file_name.
                               If there is more than 1 sitemap to be generated, consider_partition_number=1, Else 0.
    This method constructs a sitemap file for the provided category.
    The sitemap file will be created on the current directory path.
    """
    root = minidom.Document()
    urlset = root.createElement('urlset')
    root.appendChild(urlset)
    urlset.setAttribute("xmlns","http://www.sitemaps.org/schemas/sitemap/0.9")
    
    for url_link in Urls:
        url = root.createElement("url")
        loc = root.createElement("loc")
        loc.appendChild(root.createTextNode(url_link))
        url.appendChild(loc)
        
        urlset.appendChild(url)
        
    xml_str = root.toprettyxml(indent="\t", encoding="UTF-8").decode("utf-8")
    
    file_name = category_name.lower() + "_sitemap.xml"
    if consider_partition_number:
        file_name = category_name.lower() + "_sitemap_" + str(partition_number+1) + ".xml"
        
    f = open(file_name, "w")
    f.write(xml_str)
    f.close()
    
    return file_name

# %%
def createPartitionsAndBuildCategorySitemap(category_name, Urls):
    """
    This method takes category name and list of URLs as its input.
    First it calculates the number of sitemaps to be generated, decides whether to consider file part number in file name.
    Later, URLs are sliced into 50,000 blocks each for that specific category.
    Lastly, the corresponding category-specific sitemap files are created.
    This method returns all the sitemap file names for the category as its output.
    """
    
    sitemap_file_names = []
    
    # Check for 50,000 limit, else split it in parts
    num_category_sitemaps = len(Urls) // 50000
    if len(Urls) % 50000 !=0:
        num_category_sitemaps += 1
    
    consider_part_number_in_file_name = 1
    if num_category_sitemaps == 1:
        consider_part_number_in_file_name = 0
    
    for part_number in range(num_category_sitemaps):
        
        min_offset = 50000 * (part_number)
        max_offset = 50000 * (part_number + 1)
        if max_offset > len(Urls):
            max_offset = len(Urls)
        
        Url_links = Urls[min_offset : max_offset]
        file_name = buildCategorySitemap(category_name, Url_links, part_number, consider_part_number_in_file_name)
        sitemap_file_names.append(file_name)
    
    return sitemap_file_names

# %%
def createCategorywiseSitemap():
    """
    This method searches whether there are any URLs present for each category from list of pre-decided categories.
    If URLs exist for a category, these URLs are provided for creation of sitemaps.
    This method maintains sitemap file names for all the categories and returns these as its output.
    """
    
    sitemap_file_names = []
    
    for category in categories:
        
        if category in categoryUrls:
            Url_links = categoryUrls[category]
            file_names = createPartitionsAndBuildCategorySitemap(category, Url_links)
            sitemap_file_names.extend(file_names)
            
    return sitemap_file_names

# %%
def createSitemapIndex(file_names):
    """
    This method takes all the category-specific sitemap file names as input and constructs a sitemap index file.
    The sitemap index file will be created on the current directory path.
    """
    
    root = minidom.Document()
    sitemap_index = root.createElement('sitemapindex')
    root.appendChild(sitemap_index)
    sitemap_index.setAttribute("xmlns","http://www.sitemaps.org/schemas/sitemap/0.9")
    
    for sitemap_file in file_names:
        sitemap = root.createElement("sitemap")
        loc = root.createElement("loc")
        loc.appendChild(root.createTextNode(BASE_URL + "/" + sitemap_file))
        sitemap.appendChild(loc)
        
        sitemap_index.appendChild(sitemap)
        
    xml_str = root.toprettyxml(indent="\t", encoding="UTF-8").decode("utf-8")
    
    f = open("sitemap_index.xml", "w")
    f.write(xml_str)
    f.close()

# %%
sitemap_file_names = createCategorywiseSitemap()

if len(sitemap_file_names) > 0:
    createSitemapIndex(sitemap_file_names)

# %%
# We will read Sitemap Index so that we can get the names of category Sitemaps created, and access them further

f = open("sitemap_index.xml", "r")
print(f.read())
f.close()
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <sitemapindex xmlns="http://www.sitemaps.org/schemas/sitemap/0.9">
# 	<sitemap>
# 		<loc>https://www.udemy.com/course_sitemap.xml</loc>
# 	</sitemap>
# 	<sitemap>
# 		<loc>https://www.udemy.com/topic_sitemap.xml</loc>
# 	</sitemap>
# 	<sitemap>
# 		<loc>https://www.udemy.com/platform_sitemap.xml</loc>
# 	</sitemap>
# </sitemapindex>

# %%
# Reading one of the category sitemaps that we have created

f = open("platform_sitemap.xml", "r")
print(f.read())
f.close()
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9">
# 	<url>
# 		<loc>https://www.udemy.com/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/featured-topics/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/teaching/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/udemy-business/request-demo-mx/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/udemy-business/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/mobile/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/support/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/affiliate/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/terms/</loc>
# 	</url>
# 	<url>
# 		<loc>https://www.udemy.com/terms/privacy/</loc>
# 	</url>
# </urlset>

# %% [markdown]
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
#
# ### Recap Points:
#
# 1) A Sitemap file consists of a parent tag \<urlset>, which has many \<url> tags inside it, and each \<url> tag contains one mandatory child tag \<loc> that indicates URL location of the webpage.
#
# 2) \<urlset> tag has an attribute named xmlns indicating schema of the sitemap. xmlns="http://www.sitemaps.org/schemas/sitemap/0.9"
#
# 3) Maximum limit of \<url> tags in a Sitemap File: 50,000<br>
# If there are multiple sitemaps, they need to be listed in a Sitemap Index.
#
# 4) A Sitemap Index file consists of a parent tag \<sitemapindex>, which has many \<sitemap> entries inside it, and each \<sitemap> tag contains one mandatory child tag \<loc> that indicates URL location of the sitemap.
#
# 5) \<sitemapindex> tag has an attribute named xmlns indicating schema of the sitemap index. xmlns="http://www.sitemaps.org/schemas/sitemap/0.9"
#
# 6) Maximum limit of \<sitemap> tags in a Sitemap Index File: 50,000<br>
# There can be multiple sitemap index files.
#
# 7) Reference links: <br>
# https://www.sitemaps.org/protocol.html <br>
# https://developers.google.com/search/docs/crawling-indexing/sitemaps/overview <br><br>
#
# 8) Snapshot of a Sitemap:
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
# 9) Snapshot of a Sitemap Index:
#
# <img align="left" src="Screenshots/Sitemap.PNG" height="300" width="450">
#
# <img align="right" src="Screenshots/Sitemap_Index.PNG" height="400" width="500">
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>
#
# 10) Snapshot of robots.txt: <br>
# robots.txt is a file that mentions the path to the Sitemap / Sitemap Index file. This file must have the same domain as other sitemaps and sitemap index files. <br>
# A search engine obtains the sitemap path from robots.txt file, and then crawls all the sitemap and URL entries.<br><br>
# Mentioned below are snapshots for robots.txt (Considering BASE_URL as the domain name): <br>
# a) Including your Sitemap file path in robots.txt: <br>
# (If there is only 1 Sitemap for your website)
#
# <img align="left" src="Screenshots/robots1.PNG" height="400" width="500">
# <br><br><br><br><br>
#
# b) Including your Sitemap Index file path in robots.txt: <br>
# (If there are multiple Sitemap files for your website, then you'll have a Sitemap Index file created in this case)
#
# <img align="left" src="Screenshots/robots2.PNG" height="400" width="500">

# %% [markdown]
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ### Information about Image and Video Sitemaps (Extensions of Sitemap):
#
# Image Sitemap:
#
# An Image Sitemap consists all the information related to images included on your website. An Image Sitemap, in simple terms is a Sitemap having \<image:image> tag entries. <br>
# Each \<url> tag can have \<image:image> tags that contain information about an image that is on that corresponding URL page.<br>
# There can be maximum <i>1000</i> \<image:image> entries inside a \<url> tag. <br>
# \<image:loc> is a required child tag for \<image:image>.
# Note that in below sample image sitemap, we need to include xmls:image attribute for the image sitemap schema. <br>
#
# Sample Image Sitemap: <br>
# \<urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9" <br>
#     &ensp; xmlns:image="http://www.google.com/schemas/sitemap-image/1.1" > <br>
#     &emsp;\<url> <br>
#         &emsp;&emsp;\<loc> https://www.abc.com/example/ \</loc><br>
#         &emsp;&emsp;\<image:image><br>
#               &emsp;&emsp;&emsp;\<image:loc> https://www.abc.com/example/image1.png \</image:loc><br>
#         &emsp;&emsp;\</image:image><br>
#     &emsp;\</url><br>
# \</urlset>
#
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
#
# Video Sitemap:
#
# A Video Sitemap consists all videos that are a part of your website. A Video Sitemap can be described is a Sitemap having \<video:video> tag entries. It is merely same just as Image Sitemap, just the xml tags differ. <br>
# Each \<url> tag can have \<video:video> tags that contain information about videos on that corresponding URL page.<br>
# There can be maximum <i>1000</i> \<video:video> entries inside a \<url> tag. <br>
# \<video:thumbnail_loc>, \<video:title>, \<video:description>, \<video:content_loc> are the mandatory child tags for \<video:video>. There are many optional tags as well that can be included. <br>
# We need to include xmls:video attribute of \<urlset> tag for the video sitemap schema.
#
# Sample Video Sitemap: <br>
# \<urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9" <br>
# &ensp; xmlns:video="http://www.google.com/schemas/sitemap-video/1.1" ><br>
#    &ensp;\<url><br>
#      &ensp;&ensp;\<loc> https://www.abc.com/example/ \</loc><br>
#      &ensp;&ensp;\<video:video><br>
#         &ensp;&ensp; &ensp;\<video:thumbnail_loc> https://www.abc.com/example/video_thumbs/thumb1.jpg \</video:thumbnail_loc><br>
#        &ensp;&ensp; &ensp;\<video:title> A Deep Dive into abc.com Services \</video:title><br>
#        &ensp;&ensp; &ensp;\<video:description> Video that demonstrates the services provided by abc.com and getting in touch \</video:description><br>
#        &ensp;&ensp; &ensp;\<video:content_loc> https://www.abc.com/example/videoIntro.mp4 \</video:content_loc><br>
#       &ensp;&ensp;\</video:video><br>
#     &ensp;\</url><br>
# \</urlset>
#
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
#
# #### References: <br>
#
# Image Sitemap: https://developers.google.com/search/docs/crawling-indexing/sitemaps/image-sitemaps <br>
# Video Sitemap: https://developers.google.com/search/docs/crawling-indexing/sitemaps/video-sitemaps
#
# -----------------------------------------------------------------------------------------
